# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load the file 'dengue_features_train.csv', display the top 3 rows and observe the data. Then programmatically define the column names to make the following changes.

# %%
#Load the file and display top 3 rows
dengue_feature = pd.read_csv("D:\MS - BAIS\Spring 2020\DSP\Assignment\dengue_features_train.csv")
dengue_feature.head(3)
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18       4/30/1990  0.12260  0.103725  0.198483
# 1   sj  1990          19        5/7/1990  0.16990  0.142175  0.162357
# 2   sj  1990          20       5/14/1990  0.03225  0.172967  0.157200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# 1                            17.94                             77.368571
# 2                            26.10                             82.052857
#
#    reanalysis_sat_precip_amt_mm  reanalysis_specific_humidity_g_per_kg  \
# ...

# %%
dengue_feature.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
dengue_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# ...

# %% [markdown]
# a). rename columns which have 'station' such that 'station' is abbreviated to 'stn' and rest of column name remains intact. For example column name 'station_diur_temp_rng_c' is renamed to 'station_diur_tmp_rng_c'
#
# b). similarly rename columns which have 'reanalysis' to abbreviate 're_an', retaining rest of column name same
#
# c). rename columns which have 'humidity' to abbreviate to 'hd', retaining rest of column name same
#
# d). abbreviate 'precipitation' part of column name to 'prec', retaining rest of column name same

# %%
#Rename all the necessary fields as described
dengue_feature.columns = dengue_feature.columns.str.replace('station','stn')
dengue_feature.columns = dengue_feature.columns.str.replace('reanalysis','re_an')
dengue_feature.columns = dengue_feature.columns.str.replace('humidity','hd')
dengue_feature.columns = dengue_feature.columns.str.replace('precipitation','prec')
dengue_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                          1456 non-null object
# year                          1456 non-null int64
# weekofyear                    1456 non-null int64
# week_start_date               1456 non-null object
# ndvi_ne                       1262 non-null float64
# ndvi_nw                       1404 non-null float64
# ndvi_se                       1434 non-null float64
# ndvi_sw                       1434 non-null float64
# prec_amt_mm                   1443 non-null float64
# re_an_air_temp_k              1446 non-null float64
# re_an_avg_temp_k              1446 non-null float64
# re_an_dew_point_temp_k        1446 non-null float64
# re_an_max_air_temp_k          1446 non-null float64
# re_an_min_air_temp_k          1446 non-null float64
# re_an_precip_amt_kg_per_m2    1446 non-null float64
# re_an_relative_hd_percent     1446 non-null float64
# ...

# %% [markdown]
# e). view top 3 rows and recheck if column name changes have taken effect

# %%
#Display top 3 rows to see whether the renaming has taken effect
dengue_feature.info()
dengue_feature.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                          1456 non-null object
# year                          1456 non-null int64
# weekofyear                    1456 non-null int64
# week_start_date               1456 non-null object
# ndvi_ne                       1262 non-null float64
# ndvi_nw                       1404 non-null float64
# ndvi_se                       1434 non-null float64
# ndvi_sw                       1434 non-null float64
# prec_amt_mm                   1443 non-null float64
# re_an_air_temp_k              1446 non-null float64
# re_an_avg_temp_k              1446 non-null float64
# re_an_dew_point_temp_k        1446 non-null float64
# re_an_max_air_temp_k          1446 non-null float64
# re_an_min_air_temp_k          1446 non-null float64
# re_an_precip_amt_kg_per_m2    1446 non-null float64
# re_an_relative_hd_percent     1446 non-null float64
# ...

# %% [markdown]
# f). check the type of columns in dataframe

# %%
#To check the types of columns in the dataframe
dengue_feature.dtypes
# Out:
# city                           object
# year                            int64
# weekofyear                      int64
# week_start_date                object
# ndvi_ne                       float64
# ndvi_nw                       float64
# ndvi_se                       float64
# ndvi_sw                       float64
# prec_amt_mm                   float64
# re_an_air_temp_k              float64
# re_an_avg_temp_k              float64
# re_an_dew_point_temp_k        float64
# re_an_max_air_temp_k          float64
# re_an_min_air_temp_k          float64
# re_an_precip_amt_kg_per_m2    float64
# re_an_relative_hd_percent     float64
# re_an_sat_precip_amt_mm       float64
# re_an_specific_hd_g_per_kg    float64
# re_an_tdtr_k                  float64
# stn_avg_temp_c                float64
# stn_diur_temp_rng_c           float64
# stn_max_temp_c                float64
# stn_min_temp_c                float64
# stn_precip_mm                 float64
# dtype: object

# %% [markdown]
# g). Change the column 'year' as categorical variable and check if the column data type is changed and the levels of category are correct. As an example, 'city' is converted into categorical below with two categories (of cities).

# %%
#Change the year column as categorical variable
dengue_feature.year = dengue_feature.year.astype('category')

# %%
#Check to see if the column data type is changed
dengue_feature.dtypes
# Out:
# city                            object
# year                          category
# weekofyear                       int64
# week_start_date                 object
# ndvi_ne                        float64
# ndvi_nw                        float64
# ndvi_se                        float64
# ndvi_sw                        float64
# prec_amt_mm                    float64
# re_an_air_temp_k               float64
# re_an_avg_temp_k               float64
# re_an_dew_point_temp_k         float64
# re_an_max_air_temp_k           float64
# re_an_min_air_temp_k           float64
# re_an_precip_amt_kg_per_m2     float64
# re_an_relative_hd_percent      float64
# re_an_sat_precip_amt_mm        float64
# re_an_specific_hd_g_per_kg     float64
# re_an_tdtr_k                   float64
# stn_avg_temp_c                 float64
# stn_diur_temp_rng_c            float64
# stn_max_temp_c                 float64
# stn_min_temp_c                 float64
# stn_precip_mm                  float64
# dtype: object

# %%
dengue_feature.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18       4/30/1990  0.122600  0.103725  0.198483
# 1   sj  1990          19        5/7/1990  0.169900  0.142175  0.162357
# 2   sj  1990          20       5/14/1990  0.032250  0.172967  0.157200
# 3   sj  1990          21       5/21/1990  0.128633  0.245067  0.227557
# 4   sj  1990          22       5/28/1990  0.196200  0.262200  0.251200
#
#     ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_precip_amt_kg_per_m2  \
# 0  0.177617        12.42        297.572857  ...                       32.00
# 1  0.155486        22.82        298.211429  ...                       17.94
# 2  0.170843        34.54        298.781429  ...                       26.10
# 3  0.235886        15.36        298.987143  ...                       13.90
# 4  0.247340         7.52        299.518571  ...                       12.20
#
#    re_an_relative_hd_percent  re_an_sat_precip_amt_mm  \
# ...

# %% [markdown]
# The predictor column (y-value) is present in the file 'dengue_labels_train.csv'. Read this file in a new dataframe and merge it with the above dataframe using city, year and weekofyear as join conditions.

# %%
#Read the file with the predictor(y-value) into a new dataframe
dengue_labels = pd.read_csv("D:\MS - BAIS\Spring 2020\DSP\Assignment\dengue_labels_train.csv")

# %%
#Merge with previous data frame
merged = pd.merge(dengue_feature,dengue_labels, on = ['city','year','weekofyear'])

# %% [markdown]
# Count NANs in merged dataframe and use forward fill method to fill NANs (df_merged.fillna(method='ffill'))

# %%
#Total number of nulls in the pandas dataframe
merged.isnull().sum().sum()
# Out:
# 548

# %%
#Total number of nulls by each columns
merged.isnull().sum()
# Out:
# city                            0
# year                            0
# weekofyear                      0
# week_start_date                 0
# ndvi_ne                       194
# ndvi_nw                        52
# ndvi_se                        22
# ndvi_sw                        22
# prec_amt_mm                    13
# re_an_air_temp_k               10
# re_an_avg_temp_k               10
# re_an_dew_point_temp_k         10
# re_an_max_air_temp_k           10
# re_an_min_air_temp_k           10
# re_an_precip_amt_kg_per_m2     10
# re_an_relative_hd_percent      10
# re_an_sat_precip_amt_mm        13
# re_an_specific_hd_g_per_kg     10
# re_an_tdtr_k                   10
# stn_avg_temp_c                 43
# stn_diur_temp_rng_c            43
# stn_max_temp_c                 20
# stn_min_temp_c                 14
# stn_precip_mm                  22
# total_cases                     0
# dtype: int64

# %%
#Forward Fill method to fill NANs
merged.fillna(method='ffill')
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      sj  1990          18       4/30/1990  0.122600  0.103725  0.198483
# 1      sj  1990          19        5/7/1990  0.169900  0.142175  0.162357
# 2      sj  1990          20       5/14/1990  0.032250  0.172967  0.157200
# 3      sj  1990          21       5/21/1990  0.128633  0.245067  0.227557
# 4      sj  1990          22       5/28/1990  0.196200  0.262200  0.251200
# ...   ...   ...         ...             ...       ...       ...       ...
# 1451   iq  2010          21       5/28/2010  0.342750  0.318900  0.256343
# 1452   iq  2010          22        6/4/2010  0.160157  0.160371  0.136043
# 1453   iq  2010          23       6/11/2010  0.247057  0.146057  0.250357
# 1454   iq  2010          24       6/18/2010  0.333914  0.245771  0.278886
# 1455   iq  2010          25       6/25/2010  0.298186  0.232971  0.274214
#
#        ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_relative_hd_percent  \
# ...

# %% [markdown]
# a). Do a random check by printing few values from both files and merged file

# %%
#Random Check in dengue_feature_train dataset
dengue_feature.head(10)
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18       4/30/1990  0.122600  0.103725  0.198483
# 1   sj  1990          19        5/7/1990  0.169900  0.142175  0.162357
# 2   sj  1990          20       5/14/1990  0.032250  0.172967  0.157200
# 3   sj  1990          21       5/21/1990  0.128633  0.245067  0.227557
# 4   sj  1990          22       5/28/1990  0.196200  0.262200  0.251200
# 5   sj  1990          23        6/4/1990       NaN  0.174850  0.254314
# 6   sj  1990          24       6/11/1990  0.112900  0.092800  0.205071
# 7   sj  1990          25       6/18/1990  0.072500  0.072500  0.151471
# 8   sj  1990          26       6/25/1990  0.102450  0.146175  0.125571
# 9   sj  1990          27        7/2/1990       NaN  0.121550  0.160683
#
#     ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_precip_amt_kg_per_m2  \
# 0  0.177617        12.42        297.572857  ...                       32.00
# ...

# %%
#Random Check in dengue_labels_train dataset
dengue_labels.head(10)
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6
# 5   sj  1990          23            2
# 6   sj  1990          24            4
# 7   sj  1990          25            5
# 8   sj  1990          26           10
# 9   sj  1990          27            6

# %%
#Random Check in merged dataset
merged.head(10)
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18       4/30/1990  0.122600  0.103725  0.198483
# 1   sj  1990          19        5/7/1990  0.169900  0.142175  0.162357
# 2   sj  1990          20       5/14/1990  0.032250  0.172967  0.157200
# 3   sj  1990          21       5/21/1990  0.128633  0.245067  0.227557
# 4   sj  1990          22       5/28/1990  0.196200  0.262200  0.251200
# 5   sj  1990          23        6/4/1990       NaN  0.174850  0.254314
# 6   sj  1990          24       6/11/1990  0.112900  0.092800  0.205071
# 7   sj  1990          25       6/18/1990  0.072500  0.072500  0.151471
# 8   sj  1990          26       6/25/1990  0.102450  0.146175  0.125571
# 9   sj  1990          27        7/2/1990       NaN  0.121550  0.160683
#
#     ndvi_sw  prec_amt_mm  re_an_air_temp_k  ...  re_an_relative_hd_percent  \
# 0  0.177617        12.42        297.572857  ...                  73.365714
# ...

# %% [markdown]
# b). Do a scatter plot of weekofyear on x-axis and total_cases on y-axis and observe if there is a relationship.

# %%
#Scatter plot with weekofyear in x-axis and total_cases on y-axis
merged.plot(kind="scatter",x="weekofyear",y="total_cases",color='red')
plt.title('Scatter plot of Number of cases each week')
plt.xlabel('WeekNumber')
plt.ylabel('NumberOfCases')
plt.show()

# %% [markdown]
# The number of cases seems to be less than hundred in most of the weeks throughout the year with an average around 25. The outliers seem to take place in the time period between 25 to 50 weeks suggesting the dengue spreads faster during the season between 25 to 50 weeks and so the number of cases seem to be high during that time period.

# %% [markdown]
# c). Do a box plot to observe the density of data and if it complies to Central Limit Theorem (for large enough data, mean of sample is mean of population, or data is tightly packed close to the mean)

# %%
#Boxplot to observe the density of data
merged.boxplot(column='total_cases')
plt.title('Box plot of Number of cases')
plt.figure(figsize=(20,15))
plt.show()

# %% [markdown]
# The data is found to have a lots of outliers. The mean of the data and the mean of the population won't be close as the sample has many outliers in the week period between 25 to 50 weeks in terms of cases suggesting the data may not conform to a normal distribution and hence does not comply to Center Limit Theorem.

# %% [markdown]
# d). Find the mean, min, max and standard deviation of total_cases by city

# %%
#Mean of Total Cases by City
merged.groupby(['city'])['total_cases'].mean()
# Out:
# city
# iq     7.565385
# sj    34.180556
# Name: total_cases, dtype: float64

# %%
#Minimum of Total Cases by City
merged.groupby(['city'])['total_cases'].min()
# Out:
# city
# iq    0
# sj    0
# Name: total_cases, dtype: int64

# %%
#Maximum of Total Cases by City
merged.groupby(['city'])['total_cases'].max()
# Out:
# city
# iq    116
# sj    461
# Name: total_cases, dtype: int64

# %%
#Standard Deviation of Total Cases by City
merged.groupby(['city'])['total_cases'].std()
# Out:
# city
# iq    10.765478
# sj    51.381372
# Name: total_cases, dtype: float64

# %% [markdown]
# e). Read the relationship between mean and standard deviation from the link given here and describe the data of total_cases by city, if there is too much variation or too little variation https://www-users.york.ac.uk/~mb55/msc/applbio/week3/sd_text.pdf

# %%
#Relation between mean and standard deviation for total_cases by both cities
total = merged.groupby(['city'])['total_cases']
total.hist(bins=50,color='orange')
plt.title('Histogram of total cases in both cities')
plt.xlabel('TotalCases')
plt.ylabel('Frequency')
plt.show()

# %%
#Relation between mean and standard deviation for total_cases in city iq
total = merged[merged['city'] == 'iq'].groupby(['city'])['total_cases']
total.hist(bins=50,color='orange')
plt.title('Histogram of total cases in iq city')
plt.xlabel('TotalCases')
plt.ylabel('Frequency')
plt.show()

# %%
#Relation between mean and standard deviation for total_cases in city sj
total = merged[merged['city'] == 'sj'].groupby(['city'])['total_cases']
total.hist(bins=50,color='orange')
plt.title('Histogram of total cases in sj city')
plt.xlabel('TotalCases')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The histogram of the total_cases by both cities shows us the data is right skewed and the city wise histogram also suggests the same. It means the data is not normally distributed and hence the relation between mean and standard deviation is too wide. The data suggests there is too much variance.

# %% [markdown]
# How many years in the city iq have greater than or equal to 50 total_cases of dengue and in which years?

# %%
#How many years in city iq have equal to or more than 50 cases of dengue
df = merged[merged['city'] == 'iq'].groupby('year')['total_cases'].sum()
print(df[df>=50].count())
# Out:
# 9

# %%
#The years in which the number of cases were equal to or more than 50 in city iq
print(df[df>=50])
# Out:
# year
# 2002    704
# 2003    114
# 2004    638
# 2005    311
# 2006    436
# 2007    365
# 2008    801
# 2009    324
# 2010    223
# Name: total_cases, dtype: int64

# %% [markdown]
# Create a temp data frame by grouping the total_cases by weekofyear and draw a histogram of total_cases and provide insights based on the distribution

# %%
#Temp Data Frame by grouping the total_cases by weekofyear
df1 = merged.groupby('weekofyear')['total_cases'].sum()
df1.head()
print(df1)
# Out:
# weekofyear
# 1      678
# 2      728
# 3      677
# 4      652
# 5      620
# 6      530
# 7      487
# 8      478
# 9      453
# 10     387
# 11     313
# 12     279
# 13     302
# 14     239
# 15     232
# 16     239
# 17     212
# 18     241
# 19     236
# 20     254
# 21     237
# 22     296
# 23     281
# 24     305
# 25     344
# 26     404
# 27     403
# 28     464
# 29     511
# 30     633
# 31     720
# 32     898
# 33     906
# 34     920
# 35    1016
# 36    1102
# 37    1105
# 38    1109
# 39    1213
# 40    1403
# 41    1385
# 42    1345
# 43    1256
# 44    1325
# 45    1315
# 46    1164
# 47    1161
# 48    1107
# 49    1021
# 50     924
# 51     704
# 52     605
# 53     108
# Name: total_cases, dtype: int64

# %%
#Histogram of the total cases
df1.hist(bins=50,figsize=(20,15))
plt.title('Histogram of total cases by weekofyear')
plt.xlabel('TotalCases')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The data appears to be right skewed with total cases between 200 to 400 appearing the most often in a particular weekofyear among all years.
